# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
df_train = pd.read_csv('./datasets/train.csv')
df_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour    ...     Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl    ...                0         0     NaN   NaN
# 1       IR1          Lvl    ...                0         0     NaN   NaN
# 2       Reg          Lvl    ...                0         0     NaN   NaN
# 3       Reg          Lvl    ...                0         0     NaN   NaN
# 4       IR1          Lvl    ...                0         0     NaN   NaN
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       1721 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
# Filling null vales of the ints and floats
df_train = df_train.apply(lambda col: col.fillna(0) if col.dtype == 'int64' or col.dtype == 'float64' else col)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       2051 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
# Convert all columns to lowercase and replace spaces in column names.
df_train.columns = [i.lower().replace(' ', '_') for i in df_train.columns]

# %%
df_train.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           0.0     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   lot_shape land_contour    ...     screen_porch pool_area pool_qc fence  \
# 0       IR1          Lvl    ...                0         0     NaN   NaN
# 1       IR1          Lvl    ...                0         0     NaN   NaN
# 2       Reg          Lvl    ...                0         0     NaN   NaN
# 3       Reg          Lvl    ...                0         0     NaN   NaN
# 4       IR1          Lvl    ...                0         0     NaN   NaN
#
# ...

# %%
# looking at 
for _, col in enumerate(df_train):
    value_counts = df_train[col].value_counts()
    print(value_counts, 'count:', value_counts.sum())
# Out:
# 2047    1
# 2787    1
# 1058    1
# 1060    1
# 1062    1
# 1066    1
# 1068    1
# 1070    1
# 1072    1
# 1074    1
# 1076    1
# 1078    1
# 1080    1
# 1082    1
# 1084    1
# 1086    1
# 1088    1
# 1090    1
# 1094    1
# 1096    1
# 1098    1
# 1100    1
# 1102    1
# 1104    1
# 1106    1
# 1108    1
# 1110    1
# 1118    1
# 1120    1
# 1124    1
#        ..
# 2536    1
# 471     1
# 473     1
# 2522    1
# 475     1
# 2524    1
# 477     1
# 2526    1
# 479     1
# 2528    1
# 2530    1
# 485     1
# 2534    1
# 487     1
# 489     1
# 2556    1
# 491     1
# 2540    1
# 493     1
# 2542    1
# 495     1
# 2544    1
# 497     1
# 2546    1
# 2548    1
# 2550    1
# 2552    1
# 505     1
# 507     1
# 2049    1
# Name: id, Length: 2051, dtype: int64 count: 2051
# 532351060    1
# 535303150    1
# 909250210    1
# 905377130    1
# 527403020    1
# 535452060    1
# 923252080    1
# 535455090    1
# 909131125    1
# 534476150    1
# 528290170    1
# 903202170    1
# ...

# %%
df_train_corr = df_train.corr()
df_train_corr
# Out:
#                        id       pid  ms_subclass  lot_frontage  lot_area  \
# id               1.000000  0.175793     0.026543     -0.013538  0.032872
# pid              0.175793  1.000000    -0.003632     -0.038402  0.024135
# ms_subclass      0.026543 -0.003632     1.000000     -0.216259 -0.245484
# lot_frontage    -0.013538 -0.038402    -0.216259      1.000000  0.135586
# lot_area         0.032872  0.024135    -0.245484      0.135586  1.000000
# overall_qual    -0.061483 -0.265863     0.035763      0.114469  0.105824
# overall_cond    -0.026096  0.106861    -0.070141     -0.032452 -0.019185
# year_built      -0.064444 -0.347039     0.035983      0.020571  0.036002
# year_remod/add  -0.090040 -0.176666     0.044836      0.058942  0.050771
# mas_vnr_area    -0.035808 -0.242482    -0.002763      0.101672  0.167520
# bsmtfin_sf_1    -0.045794 -0.086951    -0.060425      0.056742  0.215648
# bsmtfin_sf_2     0.000745 -0.013283    -0.068129      0.001322  0.041799
# ...
